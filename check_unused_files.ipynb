# %%
# fmt: off
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"
# %load_ext autoreload
# %load_ext jupyter_black
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pickle
from mls_scf_tools.mls_pint import ureg
plt.style.use("mls_scf")
def vdir(obj):
    return [x for x in dir(obj) if not x.startswith('__')]

# %%
# This notebook looks to see which files that git is managing aren't used by LaTeX

# %%
import subprocess
from pathlib import Path
from git import Repo

# %%
# Open the fls file and extract the relevant lines
with open("v6-x-report.fls", "r", encoding="utf-8", errors="ignore") as fls_file:
    fls_lines = [line.strip() for line in fls_file.readlines()]
prefix = "INPUT "
used_files = [file[len(prefix) :] for file in fls_lines if file.startswith(prefix)]

# %%
# Now skip all the ones that come from texlive
for prefix in ["/usr/local/texlive/", "/Users/livesey/Library/texlive"]:
    used_files = [file for file in used_files if not file.startswith(prefix)]

# %%
# Remove all the "./" prefixes
used_files = [file.replace("./", "") for file in used_files]
# remove duplicates and sort
used_files = set(used_files)

# %%
# Now work out what files are managed by git
# point at the repo root (Path.cwd() if you run inside the repo)
repo = Repo(Path.cwd())
# All tracked, non-ignored files (relative paths, one per line)
tracked_files = set(repo.git.ls_files().splitlines())

# %%
tracked_but_not_used = sorted(tracked_files - used_files)

# %%
# Now work out which ones it's OK to have in this state
whitelist = [
    ".gitattributes",
    ".gitignore",
    "announcement.txt",
    "makediffs.sh",
    "mybib.bib",
    ".vscode/settings.json",
    "list-unchanged.sh",
    "notes-05feb15a.txt",
    "shortnames.bib",
    "tracking.txt",
    "v6-x-report.synctex(busy)",
    "valpaperstable.tex",
    "check_unused_files.ipynb",
]
tracked_and_not_wanted = []
for file in tracked_but_not_used:
    # Keep files that are whitelisted
    if file in whitelist:
        continue
    # Keep eps files if their pdf forebears are used
    if file.endswith(".eps") and file.replace(".eps", ".pdf") in used_files:
        continue
    # Keep the averaging kernel text files
    if file.startswith("figures/avk-") and file.endswith(".txt"):
        continue
    tracked_and_not_wanted.append(file)
tracked_and_not_wanted = sorted(tracked_and_not_wanted)

# %%
tracked_and_not_wanted
# Out:
# ['Fig-O3_v6_ZMContour_vs_v5_2009m04_StratMes.eps',
#  'Fig-O3_v6_ZMContour_vs_v5_2009m04_UTLS.eps',
#  'data/MLS_v5_1D_AVK_0N.nc4',
#  'data/MLS_v5_1D_AVK_35N.nc4',
#  'data/MLS_v5_1D_AVK_35S.nc4',
#  'data/MLS_v5_1D_AVK_70N.nc4',
#  'data/MLS_v5_1D_AVK_70S.nc4',
#  'data/MLS_v5_2D_AVK_0N.nc4',
#  'data/MLS_v5_2D_AVK_35N.nc4',
#  'data/MLS_v5_2D_AVK_35S.nc4',
#  'data/MLS_v5_2D_AVK_70N.nc4',
#  'data/MLS_v5_2D_AVK_70S.nc4',
#  'figures/CO_scatv5v4.eps',
#  'figures/CO_scatv5v4.pdf',
#  'figures/EGM96-WGS84.eps',
#  'figures/EGM96-WGS84.pdf',
#  'figures/Fig-HCl-InspectZMContour-v3-3-v4-1_2009m09.eps',
#  'figures/Fig-HCl-InspectZMContour-v3-3-v4-1_2009m09.pdf',
#  'figures/Fig-HCl-ZMContours-v3-3-v4-2_2009m03.eps',
#  'figures/Fig-HCl-ZMContours-v3-3-v4-2_2009m03.pdf',
#  'figures/Fig-HCl_v5_v4_difs_ZMContours_2009m03.eps',
#  'figures/Fig-HCl_v5_v4_difs_ZMContours_2009m03.pdf',
#  'figures/Fig-HOCl-InspectZMContour-v3-3-v4-1_2009m09.eps',
#  'figures/Fig-HOCl-InspectZMContour-v3-3-v4-1_2009m09.pdf',
#  'figures/Fig-HOCl-ZMContours-v3-3-v4-2_2009m03.eps',
#  'figures/Fig-HOCl-ZMContours-v3-3-v4-2_2009m03.pdf',
#  'figures/Fig-HOCl_v5_v4_difs_ZMContours_2009m03.eps',
#  'figures/Fig-HOCl_v5_v4_difs_ZMContours_2009m03.pdf',
#  'figures/Fig-O3-InspectZMContour-v2-2-v4-1_2009m03_StratMes.eps',
#  'figures/Fig-O3-InspectZMContour-v2-2-v4-1_2009m03_StratMes.pdf',
#  'figures/Fig-O3-InspectZMContour-v2-2-v4-1_2009m03_UTLS.eps',
#  'figures/Fig-O3-InspectZMContour-v2-2-v4-1_2009m03_UTLS.pdf',
#  'figures/Fig-O3-InspectZMContour-v3-3-v4-1_2009m03_StratMes.eps',
#  'figures/Fig-O3-InspectZMContour-v3-3-v4-1_2009m03_StratMes.pdf',
#  'figures/Fig-O3-InspectZMContour-v3-3-v4-1_2009m03_UTLS.eps',
#  'figures/Fig-O3-InspectZMContour-v3-3-v4-1_2009m03_UTLS.pdf',
#  'figures/Fig-O3-ZMContours-v2-2-v4-2_2009m03_StratMes.eps',
#  'figures/Fig-O3-ZMContours-v2-2-v4-2_2009m03_StratMes.pdf',
#  'figures/Fig-O3-ZMContours-v2-2-v4-2_2009m03_UTLS.eps',
#  'figures/Fig-O3-ZMContours-v2-2-v4-2_2009m03_UTLS.pdf',
#  'figures/Fig-O3-ZMContours-v3-3-v4-2_2009m03_StratMes.eps',
#  'figures/Fig-O3-ZMContours-v3-3-v4-2_2009m03_StratMes.pdf',
#  'figures/Fig-O3-ZMContours-v3-3-v4-2_2009m03_UTLS.eps',
#  'figures/Fig-O3-ZMContours-v3-3-v4-2_2009m03_UTLS.pdf',
#  'figures/Fig-O3_kink_v4_v3_v2_2009_March_0-10N.eps',
#  'figures/Fig-O3_kink_v4_v3_v2_2009_March_0-10N.pdf',
#  'figures/Fig-O3_kink_v4_v3_v2_2009_March_10N-20N.eps',
#  'figures/Fig-O3_kink_v4_v3_v2_2009_March_10N-20N.pdf',
#  'figures/Fig-O3_v5_ZMContour_vs_v4_2009m03_StratMes.eps',
#  'figures/Fig-O3_v5_ZMContour_vs_v4_2009m03_StratMes.pdf',
#  'figures/Fig-O3_v5_ZMContour_vs_v4_2009m03_UTLS.eps',
#  'figures/Fig-O3_v5_ZMContour_vs_v4_2009m03_UTLS.pdf',
#  'figures/Fig-O3_v5_daynight_v5_v4_2009_March_30N-60N.eps',
#  'figures/Fig-O3_v5_daynight_v5_v4_2009_March_30N-60N.pdf',
#  'figures/Fig-O3_v5_kink_v4_v3_2009_March_0-10N.eps',
#  'figures/Fig-O3_v5_kink_v4_v3_2009_March_0-10N.pdf',
#  'figures/GPH_geoid_correction2A.eps',
#  'figures/GPH_geoid_correction2A.pdf',
#  'figures/GPH_geoid_correction2D.eps',
#  'figures/GPH_geoid_correction2D.pdf',
#  'figures/GPHv0420_trend_January.eps',
#  'figures/GPHv0420_trend_January.pdf',
#  'figures/MLSv33TminusGEOS5.eps',
#  'figures/MLSv33TminusGEOS5.pdf',
#  'figures/O3_v4v3_hist_9lev_tropics.eps',
#  'figures/O3_v4v3_hist_9lev_tropics.pdf',
#  'figures/avk-N2O-190.eps',
#  'figures/avk-N2O-190.pdf',
#  'figures/binbylat_v4-ap_2005.eps',
#  'figures/binbylat_v4-ap_2005.pdf',
#  'figures/checkbins.pro',
#  'figures/co-prec-fig-2005d028.eps',
#  'figures/co-prec-fig-2005d028.pdf',
#  'figures/co-prec-fig-2006d059.eps',
#  'figures/co-prec-fig-2006d059.pdf',
#  'figures/co-prec-fig-2006d069.eps',
#  'figures/co-prec-fig-2006d069.pdf',
#  'figures/diffv4v3T_plot1bylat.eps',
#  'figures/diffv4v3T_plot1bylat.pdf',
#  'figures/doconversion.sh',
#  'figures/fix.sh',
#  'figures/geoidheight.eps',
#  'figures/geoidheight.pdf',
#  'figures/idl.ps',
#  'figures/iwp-figure-bitmap.eps',
#  'figures/iwp-figure-bitmap.pdf',
#  'figures/makepdfs.sh',
#  'figures/makepngs.sh',
#  'figures/mls_h2o_v2-v3-v4-v5-v6_prfl_60s-30s.pdf',
#  'figures/mls_h2o_v2-v3-v4-v5-v6_prfl_90s-60s.pdf',
#  'figures/mls_so2_v2-v3-v4-v5_prfl_comp_30n-60n.eps',
#  'figures/mls_so2_v2-v3-v4-v5_prfl_comp_30n-60n.pdf',
#  'figures/mls_so2_v2-v3-v4-v5_prfl_comp_30s-30n.eps',
#  'figures/mls_so2_v2-v3-v4-v5_prfl_comp_30s-30n.pdf',
#  'figures/mls_so2_v2-v3-v4-v5_prfl_comp_60n-90n.eps',
#  'figures/mls_so2_v2-v3-v4-v5_prfl_comp_60n-90n.pdf',
#  'figures/mls_so2_v2-v3-v4-v5_prfl_comp_60s-30s.eps',
#  'figures/mls_so2_v2-v3-v4-v5_prfl_comp_60s-30s.pdf',
#  'figures/mls_so2_v2-v3-v4-v5_prfl_comp_90s-60s.eps',
#  'figures/mls_so2_v2-v3-v4-v5_prfl_comp_90s-60s.pdf',
#  'figures/oneavkcombo.pro',
#  'figures/plot_ho2zmv5.eps',
#  'figures/plot_ho2zmv5.pdf',
#  'figures/plot_ohzmv5.eps',
#  'figures/plot_ohzmv5.pdf',
#  'figures/range-table.txt',
#  'figures/v4-v3_100hPaGPH_2005-2009_bylat.eps',
#  'figures/v4-v3_100hPaGPH_2005-2009_bylat.pdf',
#  'figures/v4-v3_100hPaGPH_2005_bylat.eps',
#  'figures/v4-v3_100hPaGPH_2005_bylat.pdf',
#  'figures/v4v3_215hPa_pcolorhist2.eps',
#  'figures/v4v3_215hPa_pcolorhist2.pdf',
#  'figures/v4v3_68-316hPa_linehists.eps',
#  'figures/v4v3_68-316hPa_linehists.pdf',
#  'figures/v6v5FWHMvert.pdf',
#  'figures/v6v5Precision.pdf',
#  'figures/zmprofs.R']
